# %% [markdown]
# # 01: Prepare Dataset
# Converts strategy JSON files into ShareGPT/Alpaca JSONL format for fine-tuning.

# %%
import json
import glob

def process_strategies():
    print('Processing strategies...')
    # Logic to convert strategies into QA pairs
    pass

process_strategies()
