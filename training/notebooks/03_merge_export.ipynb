# %% [markdown]
# # 03: Merge and Export
# Merge the LoRA adapter with the base model and export to GGUF.

# %%
# !pip install -q -U peft transformers

# %%
print('Merging LoRA weights with base model...')
# Merging and exporting to GGUF format via llama.cpp conversion scripts
