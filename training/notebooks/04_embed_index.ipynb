# %% [markdown]
# # 04: Embed and Index
# Embed strategies using BGE-M3 and index them into Qdrant.

# %%
# !pip install -q -U sentence-transformers qdrant-client

# %%
print('Embedding strategies and pushing to Qdrant...')
# Qdrant indexing logic here
